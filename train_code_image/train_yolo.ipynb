# %%
import os
import wandb

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: normalkim (use `wandb login --relogin` to force relogin)

# %%
HOME = './'
os.chdir(os.path.join(HOME, 'yolov5'))

# %%
IMG_SIZE = 640
BATCH_SIZE = 48
EPOCHS = 10
NUM_FOLD = 5
YOLO_MODEL = 'yolov5x6'

# %%
for fold in range(5):    
    print('FOLD NUMBER: ', fold)
    # !python train.py --img {IMG_SIZE} \
                     --batch {BATCH_SIZE} \
                     --epochs {EPOCHS} \
                     --data siim-cov19-fold{fold}.yaml \
                     --hyp '../hyp.best.yaml'
                     --weights {YOLO_MODEL}.pt \
                     --project kaggle-siim-covid \
                     --name {YOLO_MODEL}-e-{EPOCHS}-img-{IMG_SIZE}-fold-{fold}
    print('###########################################################################################\n')
# Out:
# FOLD NUMBER:  0
# train: weights=yolov5x6.pt, cfg=, data=siim-cov19-fold0.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=12, img_size=[1280], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=kaggle-siim-covid, entity=None, name=yolov5x6-e-10-img-1280-fold-0, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1
# github: ⚠️ WARNING: code is out of date by 61 commits. Use 'git pull' to update or 'git clone https://github.com/ultralytics/yolov5' to download latest.
# YOLOv5 🚀 v5.0-290-g62409ee torch 1.8.1+cu111 CUDA:0 (TITAN RTX, 24220.3125MB)
#
# ...
